# %% [markdown]
# # Top Insurance Districts data analysis #

# %%
import pandas as pd
import json
import os

#This is to direct the path to get the data as states
path="D:\\GITHUB REPO\\pulse\\data\\top\\insurance\\country\\india\\state\\"
top_state_list=os.listdir(path)
top_state_list
clm={'state':[], 'year':[],'quarter':[],'districts':[], 'total_amount':[], 'total_count':[] }

for i in top_state_list:
    p_i=path+i+"\\"
    top_yr=os.listdir(p_i)
    for j in top_yr:
        p_j=p_i+j+"\\"
        top_yr_list=os.listdir(p_j)
        for k in top_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
                districts = z['entityName']
                total_amount = z['metric']['amount']
                total_count = z['metric']['count']
                clm['districts'].append(districts)
                clm['total_amount'].append(total_amount)
                clm['total_count'].append(total_count)
                clm['state'].append(i)
                clm['year'].append(j)
                clm['quarter'].append(int(k.strip('.json')))

top_insurance_districts_df=pd.DataFrame(clm)

top_insurance_districts_df
# Out:
#                           state  year  quarter                 districts  \
# 0     andaman-&-nicobar-islands  2020        2                  nicobars
# 1     andaman-&-nicobar-islands  2020        2             south andaman
# 2     andaman-&-nicobar-islands  2020        3             south andaman
# 3     andaman-&-nicobar-islands  2020        3                  nicobars
# 4     andaman-&-nicobar-islands  2020        3  north and middle andaman
# ...                         ...   ...      ...                       ...
# 5603                west-bengal  2024        4         paschim bardhaman
# 5604                west-bengal  2024        4         paschim medinipur
# 5605                west-bengal  2024        4                     malda
# 5606                west-bengal  2024        4                     nadia
# 5607                west-bengal  2024        4           purba bardhaman
#
#       total_amount  total_count
# 0            565.0            3
# ...

# %%
top_insurance_districts_df.shape
# Out:
# (5608, 6)

# %%
top_insurance_districts_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5608 entries, 0 to 5607
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         5608 non-null   str
#  1   year          5608 non-null   str
#  2   quarter       5608 non-null   int64
#  3   districts     5608 non-null   str
#  4   total_amount  5608 non-null   float64
#  5   total_count   5608 non-null   int64
# dtypes: float64(1), int64(2), str(3)
# memory usage: 386.5 KB

# %%
q2_andaman = top_insurance_districts_df[
    (top_insurance_districts_df['state'].str.lower() == 'andaman-&-nicobar-islands') &
    (top_insurance_districts_df['quarter'] == 2)
]
print(q2_andaman[['year', 'quarter', 'districts', 'total_amount', 'total_count']])
# Out:
#     year  quarter                 districts  total_amount  total_count
# 0   2020        2                  nicobars         565.0            3
# 1   2020        2             south andaman         795.0            3
# 11  2021        2             south andaman      121104.0          105
# 12  2021        2  north and middle andaman       45311.0           28
# 13  2021        2                  nicobars       15089.0            4
# 23  2022        2             south andaman      633029.0          430
# 24  2022        2  north and middle andaman       90403.0           45
# 25  2022        2                  nicobars       56308.0           26
# 35  2023        2             south andaman     1060976.0          670
# 36  2023        2  north and middle andaman      109742.0           56
# 37  2023        2                  nicobars       62677.0           42
# 47  2024        2             south andaman     1513489.0          974
# ...

# %%
top_insurance_districts_df.describe()
# Out:
#            quarter  total_amount   total_count
# count  5608.000000  5.608000e+03   5608.000000
# mean      2.580777  2.661812e+06   1977.296897
# std       1.092919  6.842624e+06   4742.819638
# min       1.000000  3.200000e+01      1.000000
# 25%       2.000000  1.177565e+05    126.500000
# 50%       3.000000  8.024965e+05    709.000000
# 75%       4.000000  2.848404e+06   2146.250000
# max       4.000000  1.592248e+08  96935.000000

# %%
top_insurance_districts_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## CHECKING NAN ACCROSS ALL COLUMNS ##

# %%
top_insurance_districts_df.isna().sum()
# Out:
# state           0
# year            0
# quarter         0
# districts       0
# total_amount    0
# total_count     0
# dtype: int64

# %%
top_insurance_districts_df['districts'].isna().sum()
# Out:
# np.int64(0)

# %%
top_insurance_districts_df['districts']
# Out:
# 0                       nicobars
# 1                  south andaman
# 2                  south andaman
# 3                       nicobars
# 4       north and middle andaman
#                   ...
# 5603           paschim bardhaman
# 5604           paschim medinipur
# 5605                       malda
# 5606                       nadia
# 5607             purba bardhaman
# Name: districts, Length: 5608, dtype: str

# %%
top_insurance_districts_df[top_insurance_districts_df['districts'].isna()]
# Out:
# Empty DataFrame
# Columns: [state, year, quarter, districts, total_amount, total_count]
# Index: []

# %%
top_insurance_districts_df[top_insurance_districts_df['districts'].isna()]
# Out:
# Empty DataFrame
# Columns: [state, year, quarter, districts, total_amount, total_count]
# Index: []

# %% [markdown]
# ## CHECKING STATE COLUMN UNIQUE VALUES ##

# %%
top_insurance_districts_df['state'].unique()
# Out:
# <ArrowStringArray>
# [         'andaman-&-nicobar-islands',                     'andhra-pradesh',
#                   'arunachal-pradesh',                              'assam',
#                               'bihar',                         'chandigarh',
#                        'chhattisgarh', 'dadra-&-nagar-haveli-&-daman-&-diu',
#                               'delhi',                                'goa',
#                             'gujarat',                            'haryana',
#                    'himachal-pradesh',                    'jammu-&-kashmir',
#                           'jharkhand',                          'karnataka',
#                              'kerala',                             'ladakh',
#                         'lakshadweep',                     'madhya-pradesh',
#                         'maharashtra',                            'manipur',
#                           'meghalaya',                            'mizoram',
# ...

# %%
top_insurance_districts_df['state'].value_counts()
# Out:
# state
# andhra-pradesh                        190
# arunachal-pradesh                     190
# assam                                 190
# bihar                                 190
# chhattisgarh                          190
# delhi                                 190
# gujarat                               190
# haryana                               190
# himachal-pradesh                      190
# jammu-&-kashmir                       190
# jharkhand                             190
# karnataka                             190
# kerala                                190
# madhya-pradesh                        190
# maharashtra                           190
# manipur                               190
# odisha                                190
# punjab                                190
# rajasthan                             190
# tamil-nadu                            190
# telangana                             190
# uttar-pradesh                         190
# ...

# %%
top_insurance_districts_df['state'] = top_insurance_districts_df['state'].str.strip().str.title()

# %%
top_insurance_districts_df['state'].unique()
# Out:
# <ArrowStringArray>
# [         'Andaman-&-Nicobar-Islands',                     'Andhra-Pradesh',
#                   'Arunachal-Pradesh',                              'Assam',
#                               'Bihar',                         'Chandigarh',
#                        'Chhattisgarh', 'Dadra-&-Nagar-Haveli-&-Daman-&-Diu',
#                               'Delhi',                                'Goa',
#                             'Gujarat',                            'Haryana',
#                    'Himachal-Pradesh',                    'Jammu-&-Kashmir',
#                           'Jharkhand',                          'Karnataka',
#                              'Kerala',                             'Ladakh',
#                         'Lakshadweep',                     'Madhya-Pradesh',
#                         'Maharashtra',                            'Manipur',
#                           'Meghalaya',                            'Mizoram',
# ...

# %% [markdown]
# ## CHECKING Districts Column Unique Values ##

# %%
top_insurance_districts_df['districts'].unique()
# Out:
# <ArrowStringArray>
# [                'nicobars',            'south andaman',
#  'north and middle andaman',                  'nicobar',
#             'visakhapatnam',                'anantapur',
#                   'krishna',                 'chittoor',
#                       'ysr',                   'guntur',
#  ...
#         'paschim bardhaman',                    'nadia',
#           'purba medinipur',        'paschim medinipur',
#                 'darjiling',              'murshidabad',
#                'koch bihar',                   'maldah',
#           'purba bardhaman',                    'malda']
# Length: 412, dtype: str

# %%
top_insurance_districts_df[top_insurance_districts_df['districts'] == 'nicobar']
# Out:
#                         state  year  quarter districts  total_amount  \
# 52  Andaman-&-Nicobar-Islands  2024        3   nicobar       68638.0
# 56  Andaman-&-Nicobar-Islands  2024        4   nicobar      136595.0
#
#     total_count
# 52           51
# 56           77

# %%
top_insurance_districts_df['districts'] = top_insurance_districts_df['districts'].replace('nicobar', 'nicobars')

# %%
top_insurance_districts_df[top_insurance_districts_df['districts'] == 'nicobars']
# Out:
#                         state  year  quarter districts  total_amount  \
# 0   Andaman-&-Nicobar-Islands  2020        2  nicobars         565.0
# 3   Andaman-&-Nicobar-Islands  2020        3  nicobars        1448.0
# 7   Andaman-&-Nicobar-Islands  2020        4  nicobars        2747.0
# 10  Andaman-&-Nicobar-Islands  2021        1  nicobars       13244.0
# 13  Andaman-&-Nicobar-Islands  2021        2  nicobars       15089.0
# 16  Andaman-&-Nicobar-Islands  2021        3  nicobars       30539.0
# 19  Andaman-&-Nicobar-Islands  2021        4  nicobars       73561.0
# 22  Andaman-&-Nicobar-Islands  2022        1  nicobars       63852.0
# 25  Andaman-&-Nicobar-Islands  2022        2  nicobars       56308.0
# 28  Andaman-&-Nicobar-Islands  2022        3  nicobars       85640.0
# 31  Andaman-&-Nicobar-Islands  2022        4  nicobars      102155.0
# 34  Andaman-&-Nicobar-Islands  2023        1  nicobars       88146.0
# 37  Andaman-&-Nicobar-Islands  2023        2  nicobars       62677.0
# ...

# %%
top_insurance_districts_df['districts'].unique()
# Out:
# <ArrowStringArray>
# [                'nicobars',            'south andaman',
#  'north and middle andaman',            'visakhapatnam',
#                 'anantapur',                  'krishna',
#                  'chittoor',                      'ysr',
#                    'guntur',            'east godavari',
#  ...
#         'paschim bardhaman',                    'nadia',
#           'purba medinipur',        'paschim medinipur',
#                 'darjiling',              'murshidabad',
#                'koch bihar',                   'maldah',
#           'purba bardhaman',                    'malda']
# Length: 411, dtype: str

# %% [markdown]
# ## VALIDATE FINAL DATASET INTEGRITY ##

# %%
top_insurance_districts_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5608 entries, 0 to 5607
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         5608 non-null   str
#  1   year          5608 non-null   str
#  2   quarter       5608 non-null   int64
#  3   districts     5608 non-null   str
#  4   total_amount  5608 non-null   float64
#  5   total_count   5608 non-null   int64
# dtypes: float64(1), int64(2), str(3)
# memory usage: 387.2 KB

# %%
top_insurance_districts_df['year'] = top_insurance_districts_df['year'].astype('int32')
top_insurance_districts_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5608 entries, 0 to 5607
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         5608 non-null   str
#  1   year          5608 non-null   int32
#  2   quarter       5608 non-null   int64
#  3   districts     5608 non-null   str
#  4   total_amount  5608 non-null   float64
#  5   total_count   5608 non-null   int64
# dtypes: float64(1), int32(1), int64(2), str(2)
# memory usage: 343.4 KB

# %%
top_insurance_districts_df
# Out:
#                           state  year  quarter                 districts  \
# 0     Andaman-&-Nicobar-Islands  2020        2                  nicobars
# 1     Andaman-&-Nicobar-Islands  2020        2             south andaman
# 2     Andaman-&-Nicobar-Islands  2020        3             south andaman
# 3     Andaman-&-Nicobar-Islands  2020        3                  nicobars
# 4     Andaman-&-Nicobar-Islands  2020        3  north and middle andaman
# ...                         ...   ...      ...                       ...
# 5603                West-Bengal  2024        4         paschim bardhaman
# 5604                West-Bengal  2024        4         paschim medinipur
# 5605                West-Bengal  2024        4                     malda
# 5606                West-Bengal  2024        4                     nadia
# 5607                West-Bengal  2024        4           purba bardhaman
#
#       total_amount  total_count
# 0            565.0            3
# ...

# %%
top_insurance_districts_df['districts'] = top_insurance_districts_df['districts'].str.strip().str.title()

# %%
top_insurance_districts_df['districts']
# Out:
# 0                       Nicobars
# 1                  South Andaman
# 2                  South Andaman
# 3                       Nicobars
# 4       North And Middle Andaman
#                   ...
# 5603           Paschim Bardhaman
# 5604           Paschim Medinipur
# 5605                       Malda
# 5606                       Nadia
# 5607             Purba Bardhaman
# Name: districts, Length: 5608, dtype: str

# %%
top_insurance_districts_df
# Out:
#                           state  year  quarter                 districts  \
# 0     Andaman-&-Nicobar-Islands  2020        2                  Nicobars
# 1     Andaman-&-Nicobar-Islands  2020        2             South Andaman
# 2     Andaman-&-Nicobar-Islands  2020        3             South Andaman
# 3     Andaman-&-Nicobar-Islands  2020        3                  Nicobars
# 4     Andaman-&-Nicobar-Islands  2020        3  North And Middle Andaman
# ...                         ...   ...      ...                       ...
# 5603                West-Bengal  2024        4         Paschim Bardhaman
# 5604                West-Bengal  2024        4         Paschim Medinipur
# 5605                West-Bengal  2024        4                     Malda
# 5606                West-Bengal  2024        4                     Nadia
# 5607                West-Bengal  2024        4           Purba Bardhaman
#
#       total_amount  total_count
# 0            565.0            3
# ...

# %%
top_insurance_districts_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5608 entries, 0 to 5607
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         5608 non-null   str
#  1   year          5608 non-null   int32
#  2   quarter       5608 non-null   int64
#  3   districts     5608 non-null   str
#  4   total_amount  5608 non-null   float64
#  5   total_count   5608 non-null   int64
# dtypes: float64(1), int32(1), int64(2), str(2)
# memory usage: 344.1 KB

# %%
top_insurance_districts_df['districts'].unique()
# Out:
# <ArrowStringArray>
# [                'Nicobars',            'South Andaman',
#  'North And Middle Andaman',            'Visakhapatnam',
#                 'Anantapur',                  'Krishna',
#                  'Chittoor',                      'Ysr',
#                    'Guntur',            'East Godavari',
#  ...
#         'Paschim Bardhaman',                    'Nadia',
#           'Purba Medinipur',        'Paschim Medinipur',
#                 'Darjiling',              'Murshidabad',
#                'Koch Bihar',                   'Maldah',
#           'Purba Bardhaman',                    'Malda']
# Length: 411, dtype: str

# %%
top_insurance_districts_df['districts'] = top_insurance_districts_df['districts'].astype('category')

# %%
top_insurance_districts_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5608 entries, 0 to 5607
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         5608 non-null   str
#  1   year          5608 non-null   int32
#  2   quarter       5608 non-null   int64
#  3   districts     5608 non-null   category
#  4   total_amount  5608 non-null   float64
#  5   total_count   5608 non-null   int64
# dtypes: category(1), float64(1), int32(1), int64(2), str(1)
# memory usage: 269.5 KB

# %% [markdown]
# ## Create Insurance_district_top Table In Database ##

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="smart_pay",
    user="postgres",
    password="HareKrishna@143",
)
conn.autocommit = True
cur = conn.cursor()

cur.execute("""
    CREATE TABLE IF NOT EXISTS insurance_districts_top (
        id SERIAL PRIMARY KEY,
        state VARCHAR(255) NOT NULL,
        year INTEGER NOT NULL,
        quarter INTEGER NOT NULL,
        districts VARCHAR(255) NOT NULL,
        total_count BIGINT,
        total_amount NUMERIC(15, 2)
    );
""")

cur.execute("SELECT to_regclass('public.insurance_districts_top')")
print("Table exists in PostgreSQL:", cur.fetchone()[0])

conn.commit()
cur.close()
conn.close()
print("Table 'insurance_districts_top' created successfully")
# Out:
# Table exists in PostgreSQL: insurance_districts_top
# Table 'insurance_districts_top' created successfully

# %% [markdown]
# ## Inserting Data from Data Frame to Insurance_district_Top Table ##

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="smart_pay",
    user="postgres",
    password="HareKrishna@143",
)
conn.autocommit = False
cur = conn.cursor()

for _, row in top_insurance_districts_df.iterrows():
    cur.execute(
        """
        INSERT INTO insurance_districts_top (
            state,
            year,
            quarter,
            districts,
            total_count,
            total_amount
        )
        VALUES (%s, %s, %s, %s, %s, %s)
        """,
        (
            row["state"],
            row["year"],
            row["quarter"],
            row["districts"],
            row["total_count"],
            row["total_amount"],
        )
    )

conn.commit()
cur.close()
conn.close()
print("Data inserted successfully")

cur.close()
conn.close()
print("Data inserted successfully")
# Out:
# Data inserted successfully
# Data inserted successfully
